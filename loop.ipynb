# %%
loop iteration
while Look
for loop
first while Look
1counter varaiable
2condition
3 increment/decrement or chanaing in the counter varaiable.

# %%
num = 1  #  counter vaiarbale initialized with 10
while num <10:
    print("loop execuating time: " ,num-9)
    num = num + 1  # increment in the counter varaiable
# Out:
# loop execuating time:  -8
# loop execuating time:  -7
# loop execuating time:  -6
# loop execuating time:  -5
# loop execuating time:  -4
# loop execuating time:  -3
# loop execuating time:  -2
# loop execuating time:  -1
# loop execuating time:  0

# %%
counter = 0 
while counter < 5:
    print("loop count", counter + 1)
    counter = counter + 1
# Out:
# loop count 1
# loop count 2
# loop count 3
# loop count 4
# loop count 5

# %%
counter = 0 
while counter < 5:
    print("loop count", counter + 1)
    counter = counter - 1

# %%
# for
for counter in "we are learing loops"
for varaibale in collection:
    collection
    "akhskjahjha"
    [11,9,3,4, "class", "fruit"]
    (11,9,3,4, "class", "fruit")
    { 'name': "ali , 'age': 15"}
    {11, 12,5, 6, 8}
    # for varaiable in atm_list:

# %%
for item in [12,3,5,56]:
    print(item)
# Out:
# 12
# 3
# 5
# 56

# %%
items = [12,3,5,56]
for item in items:
    print(item)
# Out:
# 12
# 3
# 5
# 56

# %%
for character in "we are learing python":
    print(character)
# Out:
# w
# e
#
# a
# r
# e
#
# l
# e
# a
# r
# i
# n
# g
#
# p
# y
# t
# h
# o
# n

# %%
address = " abc bazr axy"
student_name = ["ali,'shs', 'shjh'"]
