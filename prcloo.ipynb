# %%
counter = 0 
while counter < 5:
    print("loop count", counter + 1)
    counter = counter + 1
# Out:
# loop count 1
# loop count 2
# loop count 3
# loop count 4
# loop count 5

# %%
counter = 50 
while counter >= 5:
    print("loop count", counter)
    counter = counter - 5
# Out:
# loop count 50
# loop count 45
# loop count 40
# loop count 35
# loop count 30
# loop count 25
# loop count 20
# loop count 15
# loop count 10
# loop count 5

# %%
user = 100
while user > 50:
    print("user loop", user)
    user = user - 5
# Out:
# user loop 100
# user loop 95
# user loop 90
# user loop 85
# user loop 80
# user loop 75
# user loop 70
# user loop 65
# user loop 60
# user loop 55
