# %%
counter = 0 
while counter < 5:
    print("loop count", counter + 1)
    counter = counter + 1
# Out:
# loop count 1
# loop count 2
# loop count 3
# loop count 4
# loop count 5

# %%
counter = 50 
while counter >= 5:
    print("loop count", counter)
    counter = counter - 5
# Out:
# loop count 50
# loop count 45
# loop count 40
# loop count 35
# loop count 30
# loop count 25
# loop count 20
# loop count 15
# loop count 10
# loop count 5

# %%
user = 100
while user > 50:
    print("user loop", user)
    user = user - 5
# Out:
# user loop 100
# user loop 95
# user loop 90
# user loop 85
# user loop 80
# user loop 75
# user loop 70
# user loop 65
# user loop 60
# user loop 55

# %%
doc = 20
while doc < 40:
    print("doc loop", doc)
    doc = doc + 1
# Out:
# doc loop 20
# doc loop 21
# doc loop 22
# doc loop 23
# doc loop 24
# doc loop 25
# doc loop 26
# doc loop 27
# doc loop 28
# doc loop 29
# doc loop 30
# doc loop 31
# doc loop 32
# doc loop 33
# doc loop 34
# doc loop 35
# doc loop 36
# doc loop 37
# doc loop 38
# doc loop 39

# %%
marks = 10
while marks < 40:
  print(" marks loop", marks)
  marks = marks + 1
# Out:
#  marks loop 10
#  marks loop 11
#  marks loop 12
#  marks loop 13
#  marks loop 14
#  marks loop 15
#  marks loop 16
#  marks loop 17
#  marks loop 18
#  marks loop 19
#  marks loop 20
#  marks loop 21
#  marks loop 22
#  marks loop 23
#  marks loop 24
#  marks loop 25
#  marks loop 26
#  marks loop 27
#  marks loop 28
#  marks loop 29
#  marks loop 30
#  marks loop 31
#  marks loop 32
#  marks loop 33
#  marks loop 34
#  marks loop 35
#  marks loop 36
#  marks loop 37
#  marks loop 38
#  marks loop 39
